# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
# %matplotlib inline

# %%
matplotlib.__version__
# Out:
# '3.5.1'

# %%
plt.isinteractive()
# Out:
# True

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
day_total = tips.groupby("day", as_index = False)["total_bill"].sum()

# %%
day_total
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %% [markdown]
# # LINE GRAPH

# %%
plt.plot(day_total['day'], day_total['total_bill'])  # Line Graph
plt.xlabel("Day of Week")
plt.ylabel("Total Bill")
g = plt.title("Day vs. Total Bill")

# %%
plt.title("Day-wise Total Bill")  # TITLE OF GRAPH
plt.xlabel("day")  # X-LABEL
plt.ylabel("Total Bill")   # Y-LABEL
plt.plot(day_total["day"], day_total["total_bill"], color = "red", linestyle = "dashed", linewidth = 4)  # LINE GRAPH WITH RED DASHED LINE

# %%
plt.title("Day-wise Total Bill")
plt.xlabel("day")
plt.ylabel("Total Bill")
plt.plot(day_total["day"], day_total["total_bill"], "bD--")   # COLOR = BLUE, MARKER = DIAMOND, LINESTYLE = DASHED

# %%
male = tips[tips.sex == "Male"]
maletotal = male.groupby("day", as_index = False)["total_bill"].sum()  # MALE TOTAL BILL

female = tips[tips.sex == "Female"]
femaletotal = female.groupby("day", as_index = False)["total_bill"].sum()  # FEMALE TOTAL BILL

# %%
male, female
# Out:
# (     total_bill   tip   sex smoker  day    time  size
#  1         10.34  1.66  Male     No  Sun  Dinner     3
#  2         21.01  3.50  Male     No  Sun  Dinner     3
#  3         23.68  3.31  Male     No  Sun  Dinner     2
#  5         25.29  4.71  Male     No  Sun  Dinner     4
#  6          8.77  2.00  Male     No  Sun  Dinner     2
#  ..          ...   ...   ...    ...  ...     ...   ...
#  236       12.60  1.00  Male    Yes  Sat  Dinner     2
#  237       32.83  1.17  Male    Yes  Sat  Dinner     2
#  239       29.03  5.92  Male     No  Sat  Dinner     3
#  241       22.67  2.00  Male    Yes  Sat  Dinner     2
#  242       17.82  1.75  Male     No  Sat  Dinner     2
#
#  [157 rows x 7 columns],
#       total_bill   tip     sex smoker   day    time  size
#  0         16.99  1.01  Female     No   Sun  Dinner     2
#  4         24.59  3.61  Female     No   Sun  Dinner     4
#  11        35.26  5.00  Female     No   Sun  Dinner     4
# ...

# %%
male = tips[tips.sex == "Male"]
maletotal = male.groupby("day", as_index = False)["total_bill"].sum()  # MALE TOTAL BILL

female = tips[tips.sex == "Female"]
femaletotal = female.groupby("day", as_index = False)["total_bill"].sum()  # FEMALE TOTAL BILL

plt.plot(maletotal["day"], maletotal["total_bill"], color = "red", label = "Male")
plt.plot(femaletotal["day"], femaletotal["total_bill"], color = "blue", label = "Female")
plt.legend()  # LEGEND OF GRAPH
plt.xlabel("Day")  # X-LABEL
plt.ylabel("Sum of Total Bill")  # Y-LABEL
v = plt.title("Total Bill by Sex")  # TITLE OF GRAPH
#plt.ylim(0, 1500)  # CHANGE Y-AXIS SCALE

# %%
male = tips[tips.sex == "Male"]
maletotal = male.groupby("day", as_index = False)["total_bill"].sum()  # MALE TOTAL BILL

female = tips[tips.sex == "Female"]
femaletotal = female.groupby("day", as_index = False)["total_bill"].sum()  # FEMALE TOTAL BILL

plt.plot(maletotal["day"], maletotal["total_bill"], color = "red", label = "Male")
plt.plot(femaletotal["day"], femaletotal["total_bill"], color = "blue", label = "Female")
plt.legend()  # LEGEND OF GRAPH
plt.xlabel("Day")  # X-LABEL
plt.ylabel("Sum of Total Bill")  # Y-LABEL
v = plt.title("Total Bill by Sex")  # TITLE OF GRAPH
#plt.ylim(0, 1500)  # CHANGE Y-AXIS SCALE

# %% [markdown]
# ### BAR GRAPH

# %%
#plt.bar(day_total['day'], day_total['total_bill'])
plt.bar(day_total['day'], day_total['total_bill'], color='red', width=.5)
#plt.yticks(np.arange(0,2000,step=200)) 
plt.title("Day-wise Total Bill")
t = plt.xlabel("Day")

# %% [markdown]
# ### PIE CHART

# %%
plt.title("Day-wise Total Bill")
ax = plt.pie(day_total["total_bill"], labels = day_total["day"])

# %%
plt.title("Day-wise Total Bill")
t = plt.pie(day_total["total_bill"], labels = day_total["day"], autopct = "%.2f")

# %%
ax = plt.pie(day_total["total_bill"], labels = day_total["day"], autopct = "%.2f",
           explode = (0.05, 0.05, 0.06, 0.1),
           textprops = {"color" : "blue"},
           wedgeprops = {"linewidth" : 3  })
t = plt.title("Day-wise Total Bill")

# %% [markdown]
# ### SCATTER PLOT

# %%
plt.scatter(tips["total_bill"], tips["tip"], c = "red") # SCATTER PLOT
plt.title("Total Bill vs Tip")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
plt.scatter(tips["total_bill"], tips["tip"], c = "blue")  # SCATTER PLOT
plt.title("Total Bill vs Tip")  # TITLE OF GRAPH
plt.xlabel("Total Bill")  # X-LABEL
plt.ylabel("Tip")  # Y-LABEL
plt.xlim((0, 60))  # X-SCALE
plt.ylim((0, 15))  # Y-SCALE
plt.gcf().set_size_inches(15, 5) # GET CURRENT FIGURE SIZE IN INCHES

# %%
male_trans = tips.loc[ tips.sex == "Male", :]
female_trans = tips.loc[ tips.sex == "Female", :]

# %%
plt.scatter(male_trans["total_bill"], male_trans["tip"], c = "red", marker = "+", label = "Male")
plt.scatter(female_trans["total_bill"], female_trans["tip"], c = "green", marker = "d", label = "Female")
plt.title("Total Bill vs Tip for Male and Female")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.legend()
plt.gcf().set_size_inches(15, 5)

# %%
plt.scatter(tips["size"], tips["total_bill"])
plt.title("Size vs Total Bill")
plt.xlabel("Size")
plt.ylabel("Total Bill")
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
plt.scatter(tips["size"], tips["total_bill"], c = "green", marker = "d", label = "Size vs Total Bill")
plt.title("Size vs Total Bill")
plt.xlabel("Size")
plt.ylabel("Total Bill")
plt.legend()

# %%
plt.scatter(tips["size"], tips["total_bill"], c = "red", marker = "*", label = "Size vs Tip")
plt.title("Size vs Tip")
plt.xlabel("Size")
plt.ylabel("Tip")
plt.legend()

# %% [markdown]
# ### BOX PLOT

# %%
plt.boxplot(tips["total_bill"], showmeans = True, meanline = True, showfliers = False)
plt.title("Total Bill")
# Out:
# Text(0.5, 1.0, 'Total Bill')

# %%
prop = {"color" : "red", "linestyle" : "dashed", "linewidth" : 10}
t = plt.boxplot(tips["total_bill"], showmeans = True, meanline = True, boxprops = prop, showfliers = False)

# %% [markdown]
# ### HISTOGRAM

# %%
plt.title("Total Bill Distribution")
plt.xlabel("Total Bill")
plt.ylabel("Count")
ax = plt.hist(tips["total_bill"])

# %%
plt.title("Size Distribution")
plt.xlabel("Size")
plt.ylabel("Count")
ax = plt.hist(tips["size"])

# %%
edges = range(0, 60, 10)
print(list(edges))
plt.hist(tips["total_bill"])
plt.title("Total Bill")
# Out:
# [0, 10, 20, 30, 40, 50]
# Text(0.5, 1.0, 'Total Bill')

# %%
plt.hist(tips["total_bill"], bins = 5, orientation = "horizontal")
plt.title("Total Bill")
# Out:
# Text(0.5, 1.0, 'Total Bill')

# %% [markdown]
# ### OBJECT API

# %%
ax = plt.subplot()
print(type(ax))
ax.bar(tips["day"], tips["total_bill"])
ax.set_title("Day vs Total Bill")
ax.set_xlabel("Day")
ax.set_ylabel("Total Bill")
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# Text(0, 0.5, 'Total Bill')

# %%
ax = plt.subplot()
print(type(ax))
ax.bar(day_total["day"], day_total["total_bill"])
ax.set_title("Day vs Total Bill")
ax.set_xlabel("Day")
ax.set_ylabel("Total Bill")
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# Text(0, 0.5, 'Total Bill')

# %%
fig, ax = plt.subplots(1, 3)  # 1 ROW, 2 COLUMNS
fig.suptitle("Day wise Total", fontsize = 15, color = "red")
fig.set_size_inches(15, 5)
# FIRST AXES - BAR GRAPH
ax[0].bar(tips["day"], tips["total_bill"], color = "brown")
ax[0].set_xlabel("Day")
ax[0].set_ylabel("Total Bill")
# SECOND AXES - LINE GRAPH
ax[1].plot(tips["day"], tips["total_bill"], color = "green")
ax[1].set_xlabel("Day")
ax[1].set_ylabel("Total Bill")

fig.savefig("day_tital.jpg")
# THIRD AXES - PIE CHART
#ax[2].pie(tips["size"], tips["total_bill"])
#ax[2].set_xlabel("SIZE")
#ax[2].set_ylabel("Total Bill")

# %% [markdown]
# ### TEXT

# %%
plt.plot(day_total["day"], day_total["total_bill"])
# SET LABELS FOR MARKERS
days = day_total["day"]
totals = day_total["total_bill"]
for (x, y) in zip(days, totals):
    plt.text(x, y + 100, f"{y:.0f}", fontdict = {"color" : "red", "family" : "calibri", "size" :10})
plt.text("Sun", 1600, "Sunday 1600")
# Out:
# Text(Sun, 1600, 'Sunday 1600')

# %%
import requests 
import warnings

warnings.filterwarnings('ignore')
countries_dict = requests.get("https://restcountries.com/v2/all",verify=False).json()
countries = pd.DataFrame(countries_dict)

# Take only top 5 countries by population
tc = countries.nlargest(5,'population')
plt.scatter(x = tc ['area'], y = tc ['population'])
plt.gcf().set_size_inches (8,5) # gcf () get current figure and change its size     
plt.xlabel("Area")
plt.ylabel("Population")

# set labels for dots
for i in tc.index:
     population_in_cr = tc.loc[i,'population'] // 10000000
     plt.text(tc.loc[i,'area'] + 100000, tc.loc[i,'population'], f"{tc.loc[i,'alpha3Code']}-{population_in_cr} CR")

# %%
smoker_total = tips.pivot_table(index = "day", columns = "smoker", values = "total_bill", aggfunc = sum)
#smoker_total  = pd.crosstab(tips['day'], tips['smoker'], tips['total_bill'], aggfunc=sum)

# %%
smoker_total
# Out:
# smoker     Yes       No
# day
# Thur    326.24   770.09
# Fri     252.20    73.68
# Sat     893.62   884.78
# Sun     458.28  1168.88

# %% [markdown]
# ### STACKED BAR

# %%
ax = plt.subplot()
ax.bar(smoker_total.index, height = smoker_total["Yes"], label = "Smokers", color = "red")
ax.bar(smoker_total.index, height = smoker_total["No"], bottom = smoker_total["Yes"], label = "NonSmokers", color = "blue")
ax.legend()

# %%
smoker_total.plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='day'>

# %%
smoker_total
# Out:
# smoker     Yes       No
# day
# Thur    326.24   770.09
# Fri     252.20    73.68
# Sat     893.62   884.78
# Sun     458.28  1168.88

# %%
ax = smoker_total.plot.bar()
ax.set_ylabel("Total Bill")
t = ax.set_title("Total Bill per day for Smokers vs Non-Smokers")

# %%
day_total = tips.pivot_table(index = "sex", columns = "day", values = "total_bill", aggfunc = sum)

# %%
day_total
# Out:
# day       Thur     Fri      Sat      Sun
# sex
# Male    561.44  198.57  1227.35  1269.46
# Female  534.89  127.31   551.05   357.70

# %%
day_total.plot.bar()
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
day_total.plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
day_total.plot.bar(subplots = True)
# Out:
# array([<AxesSubplot:title={'center':'Thur'}, xlabel='sex'>,
#        <AxesSubplot:title={'center':'Fri'}, xlabel='sex'>,
#        <AxesSubplot:title={'center':'Sat'}, xlabel='sex'>,
#        <AxesSubplot:title={'center':'Sun'}, xlabel='sex'>], dtype=object)

# %%
smoker_total.plot.line()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
smoker_total.plot.line(subplots = True)
# Out:
# array([<AxesSubplot:xlabel='day'>, <AxesSubplot:xlabel='day'>],
#       dtype=object)

# %%
ax = smoker_total.plot.line(subplots = True)

# %% [markdown]
# ### CROSS TAB

# %%
totals = pd.crosstab(tips["sex"], tips["day"], tips["total_bill"], aggfunc = sum)

# %%
totals
# Out:
# day       Thur     Fri      Sat      Sun
# sex
# Male    561.44  198.57  1227.35  1269.46
# Female  534.89  127.31   551.05   357.70

# %%
totals.plot(kind = "barh", figsize = (10, 5))
# Out:
# <AxesSubplot:ylabel='sex'>

# %% [markdown]
# ### LINE GRAPH

# %%
male = tips.loc[tips["sex"] == "Male"].groupby("day")["total_bill"].sum()
female = tips.loc[tips["sex"] == "Female"].groupby("day")["total_bill"].sum()

# %%
plt.plot(male, color = "green", linewidth = 5)
plt.plot(female, color = "blue", linewidth = 5)
plt.legend(["Male","Female"])

# %%
male, female.plot.bar()
# Out:
# (day
#  Thur     561.44
#  Fri      198.57
#  Sat     1227.35
#  Sun     1269.46
#  Name: total_bill, dtype: float64,
#  <AxesSubplot:xlabel='day'>)

# %%
male, female.plot.bar(subplots = True)
# Out:
# (day
#  Thur     561.44
#  Fri      198.57
#  Sat     1227.35
#  Sun     1269.46
#  Name: total_bill, dtype: float64,
#  array([<AxesSubplot:title={'center':'total_bill'}, xlabel='day'>],
#        dtype=object))

# %% [markdown]
# ### HISTOGRAM

# %%
ax = tips.hist()
print(ax)
# Out:
# [[<AxesSubplot:title={'center':'total_bill'}>
#   <AxesSubplot:title={'center':'tip'}>]
#  [<AxesSubplot:title={'center':'size'}> <AxesSubplot:>]]

# %%
ax = tips.hist()
print(ax)
ax[1, 0].set_title("Table Size")
# Out:
# [[<AxesSubplot:title={'center':'total_bill'}>
#   <AxesSubplot:title={'center':'tip'}>]
#  [<AxesSubplot:title={'center':'size'}> <AxesSubplot:>]]
# Text(0.5, 1.0, 'Table Size')

# %%
ax = tips[["total_bill", "tip"]].hist()

# %%
asia_top_10 = countries.loc[countries.region == "Asia", ["name", "population", "area"]].sort_values("population", ascending = False).head(10)

# %%
asia_top_10
# Out:
#                            name  population       area
# 48                        China  1402112000  9640011.0
# 104                       India  1380004385  3287590.0
# 105                   Indonesia   273523621  1904569.0
# 169                    Pakistan   220892331   881912.0
# 18                   Bangladesh   164689383   147570.0
# 114                       Japan   125836021   377930.0
# 176                 Philippines   109581085   342353.0
# 244                     Vietnam    97338583   331212.0
# 231                      Turkey    84339067   783562.0
# 107  Iran (Islamic Republic of)    83992953  1648195.0

# %%
fig,(ax1,ax2) = plt.subplots(2,1)  # 2 rows by 1 col 
fig.set_size_inches(15,15)
ax1.bar(asia_top_10['name'],asia_top_10['population'])
t = ax1.set_xticklabels(asia_top_10.name, rotation = 'vertical')
ax2.bar(asia_top_10['name'],asia_top_10['area'])
x = ax2.set_xticklabels(asia_top_10.name, rotation = 80)

# %%
ax = plt.subplot()
ax.bar(smoker_total.index, height = smoker_total["Yes"], label = "Smokers", color = "red")
ax.bar(smoker_total.index, height = smoker_total["No"], bottom = smoker_total["Yes"], label = "NonSmokers")
plt.legend()

# %%
ax = smoker_total.plot.bar()
