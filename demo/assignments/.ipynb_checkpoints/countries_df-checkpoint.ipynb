# %%
import pandas as pd
import requests
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
resp = requests.get("https://restcountries.com/v2/all",verify = False).json() # List of dict

# %%
df = pd.DataFrame(resp)  # Dataframe from list[dict]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            250 non-null    object
#  1   topLevelDomain  250 non-null    object
#  2   alpha2Code      250 non-null    object
#  3   alpha3Code      250 non-null    object
#  4   callingCodes    250 non-null    object
#  5   capital         245 non-null    object
#  6   altSpellings    249 non-null    object
#  7   subregion       250 non-null    object
#  8   region          250 non-null    object
#  9   population      250 non-null    int64
#  10  latlng          249 non-null    object
#  11  demonym         250 non-null    object
#  12  area            240 non-null    float64
#  13  timezones       250 non-null    object
#  14  borders         165 non-null    object
#  15  nativeName      250 non-null    object
#  16  numericCode     250 non-null    object
#  17  flags           250 non-null    object
#  18  currencies      249 non-null    object
#  19  languages       250 non-null    object
#  20  translations    250 non-null    object
#  21  flag            250 non-null    object
#  22  regionalBlocs   173 non-null    object
#  23  cioc            205 non-null    object
#  24  independent     250 non-null    bool
#  25  gini            167 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(22)
# memory usage: 49.2+ KB

# %%
df.sample(5)
# Out:
#                                    name topLevelDomain alpha2Code alpha3Code  \
# 0                           Afghanistan          [.af]         AF        AFG
# 243  Venezuela (Bolivarian Republic of)          [.ve]         VE        VEN
# 229                 Trinidad and Tobago          [.tt]         TT        TTO
# 163                                Niue          [.nu]         NU        NIU
# 237                United Arab Emirates          [.ae]         AE        ARE
#
#     callingCodes        capital  \
# 0           [93]          Kabul
# 243         [58]        Caracas
# 229          [1]  Port of Spain
# 163        [683]          Alofi
# 237        [971]      Abu Dhabi
#
#                                           altSpellings      subregion  \
# 0                                     [AF, Afġānistān]  Southern Asia
# 243  [VE, Bolivarian Republic of Venezuela, Repúbli...  South America
# 229              [TT, Republic of Trinidad and Tobago]      Caribbean
# 163                                               [NU]      Polynesia
# 237                                          [AE, UAE]   Western Asia
#
#        region  population  ... numericCode  \
# 0        Asia    40218234  ...         004
# 243  Americas    28435943  ...         862
# 229  Americas     1399491  ...         780
# 163   Oceania        1470  ...         570
# 237      Asia     9890400  ...         784
#
#                                                  flags  \
# 0    {'svg': 'https://upload.wikimedia.org/wikipedi...
# 243  {'svg': 'https://flagcdn.com/ve.svg', 'png': '...
# 229  {'svg': 'https://flagcdn.com/tt.svg', 'png': '...
# 163  {'svg': 'https://flagcdn.com/nu.svg', 'png': '...
# 237  {'svg': 'https://flagcdn.com/ae.svg', 'png': '...
#
#                                             currencies  \
# 0    [{'code': 'AFN', 'name': 'Afghan afghani', 'sy...
# 243  [{'code': 'VEF', 'name': 'Venezuelan bolívar',...
# 229  [{'code': 'TTD', 'name': 'Trinidad and Tobago ...
# 163  [{'code': 'NZD', 'name': 'New Zealand dollar',...
# 237  [{'code': 'AED', 'name': 'United Arab Emirates...
#
#                                              languages  \
# 0    [{'iso639_1': 'ps', 'iso639_2': 'pus', 'name':...
# 243  [{'iso639_1': 'es', 'iso639_2': 'spa', 'name':...
# 229  [{'iso639_1': 'en', 'iso639_2': 'eng', 'name':...
# 163  [{'iso639_1': 'en', 'iso639_2': 'eng', 'name':...
# 237  [{'iso639_1': 'ar', 'iso639_2': 'ara', 'name':...
#
#                                           translations  \
# 0    {'br': 'Afghanistan', 'pt': 'Afeganistão', 'nl...
# 243  {'br': 'Venezuela', 'pt': 'Venezuela', 'nl': '...
# 229  {'br': 'Trinidad ha Tobago', 'pt': 'Trindade e...
# 163  {'br': 'Niue', 'pt': 'Niue', 'nl': 'Niue', 'hr...
# 237  {'br': 'Emirelezhioù Arab Unanet', 'pt': 'Emir...
#
#                                                   flag  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 243                         https://flagcdn.com/ve.svg
# 229                         https://flagcdn.com/tt.svg
# 163                         https://flagcdn.com/nu.svg
# 237                         https://flagcdn.com/ae.svg
#
#                                          regionalBlocs cioc independent  gini
# 0    [{'acronym': 'SAARC', 'name': 'South Asian Ass...  AFG        True   NaN
# 243  [{'acronym': 'USAN', 'name': 'Union of South A...  VEN        True  44.8
# 229  [{'acronym': 'CARICOM', 'name': 'Caribbean Com...  TTO        True  40.3
# 163                                                NaN  NaN        True   NaN
# 237  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  UAE        True  26.0
#
# [5 rows x 26 columns]

# %%
df.nlargest(10,"population")[["name","population","area","region"]]
# Out:
#                          name  population        area    region
# 48                      China  1402112000   9640011.0      Asia
# 104                     India  1380004385   3287590.0      Asia
# 239  United States of America   329484123   9629091.0  Americas
# 105                 Indonesia   273523621   1904569.0      Asia
# 169                  Pakistan   220892331    881912.0      Asia
# 31                     Brazil   212559409   8515767.0  Americas
# 162                   Nigeria   206139587    923768.0    Africa
# 18                 Bangladesh   164689383    147570.0      Asia
# 185        Russian Federation   144104080  17124442.0    Europe
# 144                    Mexico   128932753   1964375.0  Americas

# %%
df.sort_values("population", ascending = False).iloc[:10]
# Out:
#                          name topLevelDomain alpha2Code alpha3Code  \
# 48                      China          [.cn]         CN        CHN
# 104                     India          [.in]         IN        IND
# 239  United States of America          [.us]         US        USA
# 105                 Indonesia          [.id]         ID        IDN
# 169                  Pakistan          [.pk]         PK        PAK
# 31                     Brazil          [.br]         BR        BRA
# 162                   Nigeria          [.ng]         NG        NGA
# 18                 Bangladesh          [.bd]         BD        BGD
# 185        Russian Federation          [.ru]         RU        RUS
# 144                    Mexico          [.mx]         MX        MEX
#
#     callingCodes           capital  \
# 48          [86]           Beijing
# 104         [91]         New Delhi
# 239          [1]  Washington, D.C.
# 105         [62]           Jakarta
# 169         [92]         Islamabad
# 31          [55]          Brasília
# 162        [234]             Abuja
# 18         [880]             Dhaka
# 185          [7]            Moscow
# 144         [52]       Mexico City
#
#                                           altSpellings           subregion  \
# 48   [CN, Zhōngguó, Zhongguo, Zhonghua, People's Re...        Eastern Asia
# 104   [IN, Bhārat, Republic of India, Bharat Ganrajya]       Southern Asia
# 239                [US, USA, United States of America]    Northern America
# 105    [ID, Republic of Indonesia, Republik Indonesia]  South-Eastern Asia
# 169  [PK, Pākistān, Islamic Republic of Pakistan, I...       Southern Asia
# 31   [BR, Brasil, Federative Republic of Brazil, Re...       South America
# 162  [NG, Nijeriya, Naíjíríà, Federal Republic of N...      Western Africa
# 18   [BD, People's Republic of Bangladesh, Gônôprôj...       Southern Asia
# 185  [RU, Rossiya, Russian Federation, Российская Ф...      Eastern Europe
# 144  [MX, Mexicanos, United Mexican States, Estados...       North America
#
#        region  population  ... numericCode  \
# 48       Asia  1402112000  ...         156
# 104      Asia  1380004385  ...         356
# 239  Americas   329484123  ...         840
# 105      Asia   273523621  ...         360
# 169      Asia   220892331  ...         586
# 31   Americas   212559409  ...         076
# 162    Africa   206139587  ...         566
# 18       Asia   164689383  ...         050
# 185    Europe   144104080  ...         643
# 144  Americas   128932753  ...         484
#
#                                                  flags  \
# 48   {'svg': 'https://flagcdn.com/cn.svg', 'png': '...
# 104  {'svg': 'https://flagcdn.com/in.svg', 'png': '...
# 239  {'svg': 'https://flagcdn.com/us.svg', 'png': '...
# 105  {'svg': 'https://flagcdn.com/id.svg', 'png': '...
# 169  {'svg': 'https://flagcdn.com/pk.svg', 'png': '...
# 31   {'svg': 'https://flagcdn.com/br.svg', 'png': '...
# 162  {'svg': 'https://flagcdn.com/ng.svg', 'png': '...
# 18   {'svg': 'https://flagcdn.com/bd.svg', 'png': '...
# 185  {'svg': 'https://flagcdn.com/ru.svg', 'png': '...
# 144  {'svg': 'https://flagcdn.com/mx.svg', 'png': '...
#
#                                             currencies  \
# 48   [{'code': 'CNY', 'name': 'Chinese yuan', 'symb...
# 104  [{'code': 'INR', 'name': 'Indian rupee', 'symb...
# 239  [{'code': 'USD', 'name': 'United States dollar...
# 105  [{'code': 'IDR', 'name': 'Indonesian rupiah', ...
# 169  [{'code': 'PKR', 'name': 'Pakistani rupee', 's...
# 31   [{'code': 'BRL', 'name': 'Brazilian real', 'sy...
# 162  [{'code': 'NGN', 'name': 'Nigerian naira', 'sy...
# 18   [{'code': 'BDT', 'name': 'Bangladeshi taka', '...
# 185  [{'code': 'RUB', 'name': 'Russian ruble', 'sym...
# 144  [{'code': 'MXN', 'name': 'Mexican peso', 'symb...
#
#                                              languages  \
# 48   [{'iso639_1': 'zh', 'iso639_2': 'zho', 'name':...
# 104  [{'iso639_1': 'hi', 'iso639_2': 'hin', 'name':...
# 239  [{'iso639_1': 'en', 'iso639_2': 'eng', 'name':...
# 105  [{'iso639_1': 'id', 'iso639_2': 'ind', 'name':...
# 169  [{'iso639_1': 'ur', 'iso639_2': 'urd', 'name':...
# 31   [{'iso639_1': 'pt', 'iso639_2': 'por', 'name':...
# 162  [{'iso639_1': 'en', 'iso639_2': 'eng', 'name':...
# 18   [{'iso639_1': 'bn', 'iso639_2': 'ben', 'name':...
# 185  [{'iso639_1': 'ru', 'iso639_2': 'rus', 'name':...
# 144  [{'iso639_1': 'es', 'iso639_2': 'spa', 'name':...
#
#                                           translations  \
# 48   {'br': 'Sina', 'pt': 'China', 'nl': 'China', '...
# 104  {'br': 'India', 'pt': 'Índia', 'nl': 'India', ...
# 239  {'br': 'Stadoù-Unanet', 'pt': 'Estados Unidos'...
# 105  {'br': 'Indonezia', 'pt': 'Indonésia', 'nl': '...
# 169  {'br': 'Pakistan', 'pt': 'Paquistão', 'nl': 'P...
# 31   {'br': 'Brazil', 'pt': 'Brasil', 'nl': 'Brazil...
# 162  {'br': 'Nigeria', 'pt': 'Nigéria', 'nl': 'Nige...
# 18   {'br': 'Bangladesh', 'pt': 'Bangladeche', 'nl'...
# 185  {'br': 'Rusia', 'pt': 'Rússia', 'nl': 'Rusland...
# 144  {'br': 'Mec'hiko', 'pt': 'México', 'nl': 'Mexi...
#
#                            flag  \
# 48   https://flagcdn.com/cn.svg
# 104  https://flagcdn.com/in.svg
# 239  https://flagcdn.com/us.svg
# 105  https://flagcdn.com/id.svg
# 169  https://flagcdn.com/pk.svg
# 31   https://flagcdn.com/br.svg
# 162  https://flagcdn.com/ng.svg
# 18   https://flagcdn.com/bd.svg
# 185  https://flagcdn.com/ru.svg
# 144  https://flagcdn.com/mx.svg
#
#                                          regionalBlocs cioc independent  gini
# 48                                                 NaN  CHN        True  38.5
# 104  [{'acronym': 'SAARC', 'name': 'South Asian Ass...  IND        True  35.7
# 239  [{'acronym': 'NAFTA', 'name': 'North American ...  USA        True  41.4
# 105  [{'acronym': 'ASEAN', 'name': 'Association of ...  INA        True  38.2
# 169  [{'acronym': 'SAARC', 'name': 'South Asian Ass...  PAK        True  31.6
# 31   [{'acronym': 'USAN', 'name': 'Union of South A...  BRA        True  53.4
# 162  [{'acronym': 'AU', 'name': 'African Union', 'o...  NGR        True  35.1
# 18   [{'acronym': 'SAARC', 'name': 'South Asian Ass...  BAN        True  32.4
# 185  [{'acronym': 'EEU', 'name': 'Eurasian Economic...  RUS        True  37.5
# 144  [{'acronym': 'PA', 'name': 'Pacific Alliance',...  MEX        True  45.4
#
# [10 rows x 26 columns]

# %%
df.shape
# Out:
# (250, 26)

# %%
df.groupby("region")["name"].count()
# Out:
# region
# Africa             60
# Americas           57
# Antarctic           1
# Antarctic Ocean     1
# Asia               50
# Europe             53
# Oceania            27
# Polar               1
# Name: name, dtype: int64

# %%
df.groupby("region")["population"].sum()
# Out:
# region
# Africa             1343061213
# Americas           1020973033
# Antarctic                   0
# Antarctic Ocean             0
# Asia               4604576074
# Europe              747707351
# Oceania              43119438
# Polar                    1000
# Name: population, dtype: int64

# %%
df.groupby("region")["area"].sum()
# Out:
# region
# Africa             30323497.00
# Americas           42248044.36
# Antarctic               412.00
# Antarctic Ocean          49.00
# Asia               32064971.00
# Europe             23138282.46
# Oceania             8515313.00
# Polar              14000000.00
# Name: area, dtype: float64

# %%
for n in df.name:
    if n.startswith("I"):
        print(n)
# Out:
# Iceland
# India
# Indonesia
# Ivory Coast
# Iran (Islamic Republic of)
# Iraq
# Ireland
# Isle of Man
# Israel
# Italy

# %%
df.loc[df.name.apply(lambda v : v.startswith("I")),["name","capital"]]
# Out:
#                            name       capital
# 103                     Iceland     Reykjavík
# 104                       India     New Delhi
# 105                   Indonesia       Jakarta
# 106                 Ivory Coast  Yamoussoukro
# 107  Iran (Islamic Republic of)        Tehran
# 108                        Iraq       Baghdad
# 109                     Ireland        Dublin
# 110                 Isle of Man       Douglas
# 111                      Israel     Jerusalem
# 112                       Italy          Rome

# %%
df.loc[df["area"].isnull(),["name","region"]]
# Out:
#                                              name    region
# 33           United States Minor Outlying Islands  Americas
# 78                                  French Guiana  Americas
# 90                                     Guadeloupe  Americas
# 140                                    Martinique  Americas
# 143                                       Mayotte    Africa
# 171                           Palestine, State of      Asia
# 183                                       Réunion    Africa
# 188  Saint Helena, Ascension and Tristan da Cunha    Africa
# 209  South Georgia and the South Sandwich Islands  Americas
# 216                        Svalbard and Jan Mayen    Europe

# %%
df[df.name.str.len() < 5].sample()
# Out:
#      name topLevelDomain alpha2Code alpha3Code callingCodes capital  \
# 168  Oman          [.om]         OM        OMN        [968]  Muscat
#
#                                 altSpellings     subregion region  population  \
# 168  [OM, Sultanate of Oman, Salṭanat ʻUmān]  Western Asia   Asia     5106622
#
#      ... numericCode                                              flags  \
# 168  ...         512  {'svg': 'https://flagcdn.com/om.svg', 'png': '...
#
#                                             currencies  \
# 168  [{'code': 'OMR', 'name': 'Omani rial', 'symbol...
#
#                                              languages  \
# 168  [{'iso639_1': 'ar', 'iso639_2': 'ara', 'name':...
#
#                                           translations  \
# 168  {'br': 'Oman', 'pt': 'Omã', 'nl': 'Oman', 'hr'...
#
#                            flag  \
# 168  https://flagcdn.com/om.svg
#
#                                          regionalBlocs cioc independent gini
# 168  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  OMA        True  NaN
#
# [1 rows x 26 columns]

# %%
df.currencies
# Out:
# 0      [{'code': 'AFN', 'name': 'Afghan afghani', 'sy...
# 1       [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# 2      [{'code': 'ALL', 'name': 'Albanian lek', 'symb...
# 3      [{'code': 'DZD', 'name': 'Algerian dinar', 'sy...
# 4      [{'code': 'USD', 'name': 'United States Dollar...
#                              ...
# 245    [{'code': 'XPF', 'name': 'CFP franc', 'symbol'...
# 246    [{'code': 'MAD', 'name': 'Moroccan dirham', 's...
# 247    [{'code': 'YER', 'name': 'Yemeni rial', 'symbo...
# 248    [{'code': 'ZMW', 'name': 'Zambian kwacha', 'sy...
# 249    [{'code': 'ZMW', 'name': 'Zambian kwacha', 'sy...
# Name: currencies, Length: 250, dtype: object
